# %%
#importing packages
import tensorflow as tf
from tensorflow import keras
from keras.utils import plot_model
from tensorflow.keras import layers, applications, optimizers
from keras import regularizers
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, LeakyReLU, GlobalAveragePooling2D, ZeroPadding2D, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array

from sklearn.preprocessing import MultiLabelBinarizer, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from scipy import ndimage, misc

from imgaug import augmenters as iaa
import imgaug as ia

import numpy as np
import matplotlib.pyplot as plt
from imutils import paths
import imutils
import random
import pickle
import cv2
import os
import argparse
import re
from PIL import Image
from numpy import *
from glob import glob
from datetime import datetime
from shutil import copyfile
 
import pandas as pd    
pd.set_option('display.max_rows', 500)

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell #multiple outputs in notebook
InteractiveShell.ast_node_interactivity = "all"            #

random.seed(42)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.backend.backend())
# Out:
# 1.15.0
# tensorflow

# %%
def plotImages(images_arr, name):
    random.shuffle(images_arr)
    fig, axes = plt.subplots(1,10, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img.astype('uint8'), cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    fig.savefig('{}.png'.format(name))

# %%
#google Colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
#google Colab
# !unzip drive/My\ Drive/notes_aug_heavy_lily.zip

OUTPUT = "notes_aug_heavy/"

# %%
# initialize image dimensions
IMAGE_DIMS = (158, 100, 3)
scale_percent = 100

width = int(IMAGE_DIMS[1] * scale_percent / 100)
height = int(IMAGE_DIMS[0] * scale_percent / 100)

# %%
# grab the image paths and randomly shuffle them
random.seed(42)
imagePaths = sorted(list(paths.list_images(OUTPUT)))
random.shuffle(imagePaths)

# initialize the data and labels
images_train = []
data_train = []
noteLabels = []
durationLabels = []

# create preprocessed lists of images
for imagePath in imagePaths:
    image = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, (width, height))
    ret1, image = cv2.threshold(image,127,255,cv2.THRESH_OTSU)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) #TL model needs colored, 3 channel images as input
    image = ndimage.median_filter(image, size=2)
    images_train.append(image)
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    data_train.append(image)
    
    # extract set of class labels from the image path and update the labels
    filename = imagePath.split(os.path.sep)[-1]
    duration = re.search('(breve|longa|\d\.?)', filename).group()
    note = re.search('([a-z]\'*|^\w{1}\'*)', filename).group()
    noteLabels.append(note)
    durationLabels.append(duration)

# %%
plotImages(images_train, 'images_train')

# %%
data_train = np.array(data_train)

# do some checks
data_train.shape
set(noteLabels)
set(durationLabels)
len(set(map(len, (data_train, noteLabels, durationLabels)))) == 1 #check if length of lists is the same
# Out:
# (19800, 158, 100, 3)
# {"a'", "b'", "c''", "d'", "d''", "e'", "e''", "f'", "f''", "g'", "g''"}
# {'1', '2', '4', '8', 'breve', 'longa'}
# True

# %%
# convert the label lists to NumPy arrays prior to binarization
noteLabels = np.array(noteLabels)
durationLabels = np.array(durationLabels)
 
# binarize both sets of labels
noteLB = LabelBinarizer()
durationLB = LabelBinarizer()
noteLabels = noteLB.fit_transform(noteLabels)
durationLabels = durationLB.fit_transform(durationLabels)

trainX, testX, trainNoteY, testNoteY, trainDurationY, testDurationY = train_test_split(data_train,
                                    noteLabels, durationLabels, random_state=666, train_size=0.75)

# %%
# do some checks

print("We have {} training images and {} test images, with a total of {} images. The images have a height of {} and a width of {} with {} channel(s). There are {} different note classes and {} different duration classes.".format(trainX.shape[0], testX.shape[0], data_train.shape[0], data_train.shape[1], data_train.shape[2], data_train.shape[3], trainNoteY.shape[1], trainDurationY.shape[1]))
# Out:
# We have 14850 training images and 4950 test images, with a total of 19800 images. The images have a height of 158 and a width of 100 with 3 channel(s). There are 11 different note classes and 6 different duration classes.

# %% [markdown]
# # Transfer Model

# %%
# base_model = applications.inception_v3.InceptionV3(weights = "imagenet", include_top=False, input_shape = (158, 100, 3))
base_model = keras.applications.resnet_v2.ResNet50V2(include_top=False, weights='imagenet', input_shape = (158, 100, 3))

# %%
for layer in base_model.layers[:28]:
    layer.trainable = False

# %%
pd.set_option('max_colwidth', -1)
layers = [(layer, layer.name, layer.trainable) for layer in base_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                                      Layer Type  ... Layer Trainable
# 0    <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fb2f918deb8>            ...  False
# 1    <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f9e36e10>       ...  False
# 2    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f9e36c18>              ...  False
# 3    <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f97642e8>       ...  False
# 4    <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb2f9e36d30>              ...  False
# 5    <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f9764320>  ...  False
# 6    <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f98d1898>                   ...  False
# 7    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f96c3240>              ...  False
# 8    <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f96e6550>  ...  False
# 9    <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f968c828>                   ...  False
# 10   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f96e6588>       ...  False
# 11   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f95c6f28>              ...  False
# 12   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f95d2fd0>  ...  False
# 13   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f94ba780>                   ...  False
# 14   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f98d19e8>              ...  False
# 15   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f95d27b8>              ...  False
# 16   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f9451940>                         ...  False
# 17   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f9439b38>  ...  False
# 18   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f96f47f0>                   ...  False
# 19   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f945ef60>              ...  False
# 20   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f957be80>  ...  False
# 21   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f959ba90>                   ...  False
# 22   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f95911d0>       ...  False
# 23   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f959bac8>              ...  False
# 24   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f650f9b0>  ...  False
# 25   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f649c3c8>                   ...  False
# 26   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f650f9e8>              ...  False
# 27   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f64c8be0>                         ...  False
# 28   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f649c400>  ...  True
# 29   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f64db470>                   ...  True
# 30   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5c77e80>              ...  True
# 31   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5c84828>  ...  True
# 32   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f918d898>                   ...  True
# 33   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb360f93198>       ...  True
# 34   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5c97438>              ...  True
# 35   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5c9afd0>  ...  True
# 36   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f91aa9b0>                   ...  True
# 37   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb2f64d45c0>              ...  True
# 38   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5c9ab00>              ...  True
# 39   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f91d8240>                         ...  True
# 40   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f91e2c50>  ...  True
# 41   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f91cca58>                   ...  True
# 42   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f93781d0>              ...  True
# 43   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f938c748>  ...  True
# 44   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f93740f0>                   ...  True
# 45   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f938c780>       ...  True
# 46   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f920de48>              ...  True
# 47   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f9202f28>  ...  True
# 48   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f921f908>                   ...  True
# 49   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f91cef60>              ...  True
# 50   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f9202f60>              ...  True
# 51   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f923a198>                         ...  True
# 52   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f925be80>  ...  True
# 53   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f923f9b0>                   ...  True
# 54   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f923cc18>              ...  True
# 55   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f92fff28>  ...  True
# 56   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f931fb00>                   ...  True
# 57   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f9322128>       ...  True
# 58   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f931fb38>              ...  True
# 59   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f92a5908>  ...  True
# 60   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f9296320>                   ...  True
# 61   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f92a5940>              ...  True
# 62   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f92dea58>                         ...  True
# 63   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f9296358>  ...  True
# 64   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f92c93c8>                   ...  True
# 65   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f92dea20>              ...  True
# 66   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f93699b0>  ...  True
# 67   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f9362518>                   ...  True
# 68   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f9369978>       ...  True
# 69   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5c25ef0>              ...  True
# 70   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5c25e10>  ...  True
# 71   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5c32cf8>                   ...  True
# 72   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5c2c358>              ...  True
# 73   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5be0358>                         ...  True
# 74   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5c45400>  ...  True
# 75   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5beeda0>                   ...  True
# 76   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5b9e6a0>              ...  True
# 77   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5ba4a20>  ...  True
# 78   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5baf438>                   ...  True
# 79   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f5ba4a58>       ...  True
# 80   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5bd2048>              ...  True
# 81   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5bd96d8>  ...  True
# 82   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5b65c18>                   ...  True
# 83   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb2f5be7b70>              ...  True
# 84   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5b5e278>              ...  True
# 85   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5b97518>                         ...  True
# 86   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5b7a320>  ...  True
# 87   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5b23cc0>                   ...  True
# 88   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5b555f8>              ...  True
# 89   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5ae1cc0>  ...  True
# 90   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5aef6a0>                   ...  True
# 91   <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f5ae1cf8>       ...  True
# 92   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5b19e80>              ...  True
# 93   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5a9e4e0>  ...  True
# 94   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5aa5e80>                   ...  True
# 95   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5b1de10>              ...  True
# 96   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5aac048>              ...  True
# 97   <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5ad74e0>                         ...  True
# 98   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5ad1588>  ...  True
# 99   <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5a67278>                   ...  True
# 100  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5ad7630>              ...  True
# 101  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5a99748>  ...  True
# 102  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5a23160>                   ...  True
# 103  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f5a99550>       ...  True
# 104  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5a4c9e8>              ...  True
# 105  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5a55e48>  ...  True
# 106  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f59df828>                   ...  True
# 107  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5a55e80>              ...  True
# 108  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5a0e080>                         ...  True
# 109  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5a0aeb8>  ...  True
# 110  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f599cba8>                   ...  True
# 111  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5a17f98>              ...  True
# 112  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f59ca710>  ...  True
# 113  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f595b9b0>                   ...  True
# 114  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f59ca3c8>       ...  True
# 115  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5986a90>              ...  True
# 116  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f598b7f0>  ...  True
# 117  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f59971d0>                   ...  True
# 118  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f598b828>              ...  True
# 119  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5942828>                         ...  True
# 120  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5997358>  ...  True
# 121  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5956588>                   ...  True
# 122  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f594f518>              ...  True
# 123  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f59065c0>  ...  True
# 124  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5912358>                   ...  True
# 125  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f5906b70>       ...  True
# 126  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f58b8da0>              ...  True
# 127  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f58bfc88>  ...  True
# 128  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f58cdb38>                   ...  True
# 129  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f58c6198>              ...  True
# 130  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f587e3c8>                         ...  True
# 131  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f58615f8>  ...  True
# 132  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f588beb8>                   ...  True
# 133  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f58829b0>              ...  True
# 134  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f583ccf8>  ...  True
# 135  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5849cc0>                   ...  True
# 136  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f58422e8>       ...  True
# 137  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5849cf8>              ...  True
# 138  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f57fab00>  ...  True
# 139  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f58074e0>                   ...  True
# 140  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f57fab38>              ...  True
# 141  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f57b0780>                         ...  True
# 142  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5807518>  ...  True
# 143  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f57c1898>                   ...  True
# 144  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f57d9b00>              ...  True
# 145  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5774dd8>  ...  True
# 146  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5782b38>                   ...  True
# 147  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f577b198>       ...  True
# 148  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f5782b70>              ...  True
# 149  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f57339b0>  ...  True
# 150  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f573d390>                   ...  True
# 151  <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb2f57bc828>              ...  True
# 152  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f57339e8>              ...  True
# 153  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f56e9be0>                         ...  True
# 154  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f573d3c8>  ...  True
# 155  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f56f6748>                   ...  True
# 156  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f56aec50>              ...  True
# 157  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f56ae8d0>  ...  True
# 158  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f56c4d68>                   ...  True
# 159  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f56bf3c8>       ...  True
# 160  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f56c4da0>              ...  True
# 161  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f567aba8>  ...  True
# 162  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5686588>                   ...  True
# 163  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f56f86d8>              ...  True
# 164  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f567abe0>              ...  True
# 165  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f5629c50>                         ...  True
# 166  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5630b00>  ...  True
# 167  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5643908>                   ...  True
# 168  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f563d9e8>              ...  True
# 169  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f55f3da0>  ...  True
# 170  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f5602710>                   ...  True
# 171  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f55f3a90>       ...  True
# 172  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f55adc18>              ...  True
# 173  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f55b2550>  ...  True
# 174  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f55b8f28>                   ...  True
# 175  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f55bd0b8>              ...  True
# 176  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f556a438>                         ...  True
# 177  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f5562908>  ...  True
# 178  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f557c2e8>                   ...  True
# 179  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f556a2e8>              ...  True
# 180  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f552f748>  ...  True
# 181  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f55380b8>                   ...  True
# 182  <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x7fb2f552f668>       ...  True
# 183  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f54e1f98>              ...  True
# 184  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f54e5eb8>  ...  True
# 185  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f54f3898>                   ...  True
# 186  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb2f54e5ef0>              ...  True
# 187  <tensorflow.python.keras.layers.merge.Add object at 0x7fb2f54a50f0>                         ...  True
# 188  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb2f549d940>  ...  True
# 189  <tensorflow.python.keras.layers.core.Activation object at 0x7fb2f54b0c50>                   ...  True
#
# [190 rows x 3 columns]

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.2)(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.2)(x)
note_output = Dense(len(noteLB.classes_), activation='softmax', name = "note_output")(x)
duration_output = Dense(len(durationLB.classes_), activation='softmax', name = "duration_output")(x)

model = Model(inputs=base_model.input, outputs=[note_output, duration_output])

# %%
# do some checks
model.summary()
model.input_shape
model.output_shape
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 158, 100, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 164, 106, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 79, 50, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 81, 52, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 40, 25, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 40, 25, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 40, 25, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 40, 25, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 40, 25, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 40, 25, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 42, 27, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 40, 25, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 40, 25, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 40, 25, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 40, 25, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 40, 25, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 40, 25, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 40, 25, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 40, 25, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 40, 25, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 40, 25, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 40, 25, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 42, 27, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 40, 25, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 40, 25, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 40, 25, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 40, 25, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 40, 25, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 40, 25, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 40, 25, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 40, 25, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 40, 25, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 40, 25, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 42, 27, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 20, 13, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 20, 13, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 20, 13, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 20, 13, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 20, 13, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 20, 13, 256)  0           max_pooling2d[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 20, 13, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 20, 13, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 20, 13, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 20, 13, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 22, 15, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 20, 13, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 20, 13, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 20, 13, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 20, 13, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 20, 13, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 20, 13, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 20, 13, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 20, 13, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 20, 13, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 22, 15, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 20, 13, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 20, 13, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 20, 13, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 20, 13, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 20, 13, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 20, 13, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 20, 13, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 20, 13, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 22, 15, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 20, 13, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 20, 13, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 20, 13, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 20, 13, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 20, 13, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 20, 13, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 20, 13, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 20, 13, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 20, 13, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 22, 15, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 10, 7, 128)   147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 10, 7, 128)   512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 10, 7, 128)   0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 10, 7, 512)   0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 10, 7, 512)   66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 10, 7, 512)   0           max_pooling2d_1[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 10, 7, 512)   2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 10, 7, 512)   0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 10, 7, 256)   131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 10, 7, 256)   0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 10, 7, 256)   589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 10, 7, 256)   0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 10, 7, 1024)  525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 10, 7, 1024)  263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 10, 7, 1024)  0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 10, 7, 1024)  4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 10, 7, 1024)  0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 10, 7, 256)   262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 10, 7, 256)   0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 10, 7, 256)   589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 10, 7, 256)   0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 10, 7, 1024)  263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 10, 7, 1024)  0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 10, 7, 1024)  4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 10, 7, 1024)  0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 10, 7, 256)   262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 10, 7, 256)   0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 10, 7, 256)   589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 10, 7, 256)   0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 10, 7, 1024)  263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 10, 7, 1024)  0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 10, 7, 1024)  4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 10, 7, 1024)  0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 10, 7, 256)   262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 10, 7, 256)   0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 10, 7, 256)   589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 10, 7, 256)   0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 10, 7, 1024)  263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 10, 7, 1024)  0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 10, 7, 1024)  4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 10, 7, 1024)  0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 10, 7, 256)   262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 10, 7, 256)   0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 10, 7, 256)   589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 10, 7, 256)   0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 10, 7, 1024)  263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 10, 7, 1024)  0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 10, 7, 1024)  4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 10, 7, 1024)  0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 10, 7, 256)   262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 10, 7, 256)   1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 10, 7, 256)   0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 12, 9, 256)   0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 5, 4, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 5, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 5, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 4, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 5, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 5, 4, 1024)   0           max_pooling2d_2[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 5, 4, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 5, 4, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 5, 4, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 5, 4, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 7, 6, 512)    0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 5, 4, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 5, 4, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 5, 4, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 5, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 5, 4, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 5, 4, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 5, 4, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 5, 4, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 5, 4, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 7, 6, 512)    0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 5, 4, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 5, 4, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 5, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 5, 4, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 5, 4, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 5, 4, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 5, 4, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 5, 4, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 7, 6, 512)    0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 5, 4, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 5, 4, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 5, 4, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 5, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 5, 4, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 5, 4, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 5, 4, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 40960)        0           post_relu[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          10486016    flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# note_output (Dense)             (None, 11)           2827        dropout_1[0][0]
# __________________________________________________________________________________________________
# duration_output (Dense)         (None, 6)            1542        dropout_1[0][0]
# ==================================================================================================
# Total params: 34,120,977
# Trainable params: 33,920,785
# Non-trainable params: 200,192
# __________________________________________________________________________________________________
# (None, 158, 100, 3)
# [(None, 11), (None, 6)]

# %%
# compile model
epochs = 80
batch_size = 128

# define two dictionaries: one that specifies the loss method for
# each output of the network along with a second dictionary that
# specifies the weight per loss
losses = {
    "note_output": "categorical_crossentropy",
    "duration_output": "categorical_crossentropy",}
lossWeights = {"note_output": 1.0, "duration_output": 1.0}
 
# initialize the optimizer and compile the model
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rms = optimizers.RMSprop(learning_rate=0.001, rho=0.9)
adam = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
nadam = optimizers.Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=adam, loss=losses, loss_weights=lossWeights, metrics=["accuracy"])

# %%
# callbacks
early_stopping = EarlyStopping(monitor='val_note_output_acc', patience=12, mode = 'max', verbose = 1)

reduce_lr = ReduceLROnPlateau(patience=8, monitor='val_loss', factor=0.3, min_lr=0.00001, cooldown=1, verbose=1)

checkpoint = ModelCheckpoint("/Users/annaleid/Documents/Jordy/Trained Models/",
        monitor='val_acc', 
        save_best_only=True, 
        mode='max',
        verbose=0)

# %%
# # train the network to perform multi-output classification
H = model.fit(trainX, {"note_output": trainNoteY, "duration_output": trainDurationY},
    validation_data=(testX, {"note_output": testNoteY, "duration_output": testDurationY}),
    epochs=epochs,
    verbose=1,
    callbacks = [reduce_lr, early_stopping])
# Out:
# Train on 14850 samples, validate on 4950 samples
# Epoch 1/80
# 14850/14850 [==============================] - 160s 11ms/sample - loss: 0.5946 - note_output_loss: 0.3661 - duration_output_loss: 0.2275 - note_output_acc: 0.8923 - duration_output_acc: 0.9327 - val_loss: 0.4964 - val_note_output_loss: 0.2399 - val_duration_output_loss: 0.2558 - val_note_output_acc: 0.9378 - val_duration_output_acc: 0.9446
# Epoch 2/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.1287 - note_output_loss: 0.0663 - duration_output_loss: 0.0626 - note_output_acc: 0.9839 - duration_output_acc: 0.9858 - val_loss: 7.2631 - val_note_output_loss: 5.4067 - val_duration_output_loss: 1.8502 - val_note_output_acc: 0.6683 - val_duration_output_acc: 0.7721
# Epoch 3/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.1205 - note_output_loss: 0.0663 - duration_output_loss: 0.0540 - note_output_acc: 0.9870 - duration_output_acc: 0.9869 - val_loss: 0.0517 - val_note_output_loss: 0.0260 - val_duration_output_loss: 0.0259 - val_note_output_acc: 0.9909 - val_duration_output_acc: 0.9919
# Epoch 4/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0689 - note_output_loss: 0.0354 - duration_output_loss: 0.0333 - note_output_acc: 0.9919 - duration_output_acc: 0.9921 - val_loss: 0.3126 - val_note_output_loss: 0.0805 - val_duration_output_loss: 0.2321 - val_note_output_acc: 0.9745 - val_duration_output_acc: 0.9398
# Epoch 5/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0538 - note_output_loss: 0.0304 - duration_output_loss: 0.0232 - note_output_acc: 0.9934 - duration_output_acc: 0.9945 - val_loss: 0.3656 - val_note_output_loss: 0.1399 - val_duration_output_loss: 0.2256 - val_note_output_acc: 0.9598 - val_duration_output_acc: 0.9418
# Epoch 6/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0579 - note_output_loss: 0.0294 - duration_output_loss: 0.0284 - note_output_acc: 0.9935 - duration_output_acc: 0.9931 - val_loss: 0.2636 - val_note_output_loss: 0.0404 - val_duration_output_loss: 0.2236 - val_note_output_acc: 0.9883 - val_duration_output_acc: 0.9420
# Epoch 7/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0695 - note_output_loss: 0.0323 - duration_output_loss: 0.0370 - note_output_acc: 0.9923 - duration_output_acc: 0.9909 - val_loss: 1.0391 - val_note_output_loss: 0.0545 - val_duration_output_loss: 0.9853 - val_note_output_acc: 0.9855 - val_duration_output_acc: 0.7933
# Epoch 8/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0641 - note_output_loss: 0.0323 - duration_output_loss: 0.0317 - note_output_acc: 0.9927 - duration_output_acc: 0.9933 - val_loss: 0.5792 - val_note_output_loss: 0.0254 - val_duration_output_loss: 0.5526 - val_note_output_acc: 0.9943 - val_duration_output_acc: 0.9123
# Epoch 9/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0393 - note_output_loss: 0.0210 - duration_output_loss: 0.0182 - note_output_acc: 0.9957 - duration_output_acc: 0.9953 - val_loss: 0.0652 - val_note_output_loss: 0.0292 - val_duration_output_loss: 0.0358 - val_note_output_acc: 0.9897 - val_duration_output_acc: 0.9897
# Epoch 10/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0802 - note_output_loss: 0.0458 - duration_output_loss: 0.0344 - note_output_acc: 0.9904 - duration_output_acc: 0.9921 - val_loss: 0.3575 - val_note_output_loss: 0.0416 - val_duration_output_loss: 0.3155 - val_note_output_acc: 0.9883 - val_duration_output_acc: 0.9212
# Epoch 11/80
# 14848/14850 [============================>.] - ETA: 0s - loss: 0.0422 - note_output_loss: 0.0197 - duration_output_loss: 0.0226 - note_output_acc: 0.9952 - duration_output_acc: 0.9940
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 14850/14850 [==============================] - 149s 10ms/sample - loss: 0.0422 - note_output_loss: 0.0196 - duration_output_loss: 0.0225 - note_output_acc: 0.9952 - duration_output_acc: 0.9940 - val_loss: 0.0553 - val_note_output_loss: 0.0350 - val_duration_output_loss: 0.0205 - val_note_output_acc: 0.9903 - val_duration_output_acc: 0.9943
# Epoch 12/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0126 - note_output_loss: 0.0046 - duration_output_loss: 0.0080 - note_output_acc: 0.9988 - duration_output_acc: 0.9982 - val_loss: 0.0994 - val_note_output_loss: 0.0327 - val_duration_output_loss: 0.0665 - val_note_output_acc: 0.9917 - val_duration_output_acc: 0.9729
# Epoch 13/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0058 - note_output_loss: 0.0021 - duration_output_loss: 0.0114 - note_output_acc: 0.9995 - duration_output_acc: 0.9991 - val_loss: 0.0939 - val_note_output_loss: 0.0339 - val_duration_output_loss: 0.0599 - val_note_output_acc: 0.9913 - val_duration_output_acc: 0.9776
# Epoch 14/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0105 - note_output_loss: 0.0049 - duration_output_loss: 0.0057 - note_output_acc: 0.9985 - duration_output_acc: 0.9982 - val_loss: 0.2740 - val_note_output_loss: 0.1681 - val_duration_output_loss: 0.1065 - val_note_output_acc: 0.9659 - val_duration_output_acc: 0.9596
# Epoch 15/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0027 - note_output_loss: 0.0013 - duration_output_loss: 0.0014 - note_output_acc: 0.9997 - duration_output_acc: 0.9996 - val_loss: 0.2218 - val_note_output_loss: 0.1068 - val_duration_output_loss: 0.1149 - val_note_output_acc: 0.9756 - val_duration_output_acc: 0.9568
# Epoch 16/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0018 - note_output_loss: 8.4109e-04 - duration_output_loss: 9.5888e-04 - note_output_acc: 0.9998 - duration_output_acc: 0.9997 - val_loss: 0.1790 - val_note_output_loss: 0.0714 - val_duration_output_loss: 0.1090 - val_note_output_acc: 0.9816 - val_duration_output_acc: 0.9590
# Epoch 17/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0043 - note_output_loss: 0.0034 - duration_output_loss: 9.7677e-04 - note_output_acc: 0.9991 - duration_output_acc: 0.9998 - val_loss: 0.1811 - val_note_output_loss: 0.0414 - val_duration_output_loss: 0.1396 - val_note_output_acc: 0.9889 - val_duration_output_acc: 0.9545
# Epoch 18/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0035 - note_output_loss: 0.0015 - duration_output_loss: 0.0020 - note_output_acc: 0.9995 - duration_output_acc: 0.9995 - val_loss: 0.2266 - val_note_output_loss: 0.0490 - val_duration_output_loss: 0.1775 - val_note_output_acc: 0.9844 - val_duration_output_acc: 0.9507
# Epoch 19/80
# 14848/14850 [============================>.] - ETA: 0s - loss: 0.0062 - note_output_loss: 0.0040 - duration_output_loss: 0.0022 - note_output_acc: 0.9989 - duration_output_acc: 0.9995
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0062 - note_output_loss: 0.0040 - duration_output_loss: 0.0022 - note_output_acc: 0.9989 - duration_output_acc: 0.9995 - val_loss: 0.2027 - val_note_output_loss: 0.0517 - val_duration_output_loss: 0.1507 - val_note_output_acc: 0.9842 - val_duration_output_acc: 0.9590
# Epoch 20/80
# 14850/14850 [==============================] - 148s 10ms/sample - loss: 0.0034 - note_output_loss: 8.0203e-04 - duration_output_loss: 0.0026 - note_output_acc: 0.9998 - duration_output_acc: 0.9993 - val_loss: 0.1425 - val_note_output_loss: 0.0212 - val_duration_output_loss: 0.1210 - val_note_output_acc: 0.9939 - val_duration_output_acc: 0.9651
# Epoch 00020: early stopping

# %%
n_epochs = len(H.history['loss'])

# plot the total loss, category loss, and color loss
lossNames = ["loss", "note_output_loss", "duration_output_loss"]
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))
 
# loop over the loss names
for (i, l) in enumerate(lossNames):
    # plot the loss for both the training and validation data
    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
    ax[i].set_title(title)
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Loss")
    ax[i].plot(np.arange(0, n_epochs), H.history[l], label=l)
    ax[i].plot(np.arange(0, n_epochs), H.history["val_" + l],
        label="val_" + l)
    ax[i].legend()
 
# save the losses figure and create a new figure for the accuracies
plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Total loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')
# Text(0.5, 1.0, 'Loss for note_output_loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')
# Text(0.5, 1.0, 'Loss for duration_output_loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')

# %%
# create a new figure for the accuracies
accuracyNames = ["note_output_acc", "duration_output_acc"]
plt.style.use("ggplot")
(fig, ax) = plt.subplots(2, 1, figsize=(8, 8))
 
# loop over the accuracy names
for (i, l) in enumerate(accuracyNames):
    # plot the loss for both the training and validation data
    ax[i].set_title("Accuracy for {}".format(l))
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Accuracy")
    ax[i].plot(np.arange(0, n_epochs), H.history[l], label=l)
    ax[i].plot(np.arange(0, n_epochs), H.history["val_" + l],
        label="val_" + l)
    ax[i].legend()
 
# save the accuracies figure
plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Accuracy for note_output_acc')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Accuracy for duration_output_acc')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# # Test Images

# %%
#Google Colab
# !unzip drive/My\ Drive/testimages.zip

# %%
folder_test = "testimages/"
imagePaths = sorted(list(paths.list_images(folder_test)))

##### Create list with arrays and labels of test images

# initialize the data and labels
images_test_original = []
images_test = []
data_test = []
noteLabels_test = []
durationLabels_test = []

for imagePath in imagePaths:
    image = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)
    images_test_original.append(image)
    image = cv2.resize(image, (width, height))
    ret1, image = cv2.threshold(image, 50,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) #TL model needs colored, 3 channel images as input
    image = ndimage.median_filter(image, size=2)
    images_test.append(image)
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    data_test.append(image)
    
    # extract set of class labels from the image path and update the labels
    # update the respective lists
    filename = imagePath.split(os.path.sep)[-1]
    duration = re.search('(breve|longa|maxima|\d\.?)', filename).group()
    note = re.search('([a-z]\'*|^\w{1}\'*)', filename).group()
    noteLabels_test.append(note)
    durationLabels_test.append(duration)

# %%
plotImages(images_test_original, 'test_original')

# %%
plotImages(images_test, 'test_preprocessed')

# %%
data_test = np.array(data_test)

# %%
set(noteLabels_test)
set(durationLabels_test)
len(set(map(len, (data_test, noteLabels_test, durationLabels_test)))) == 1 #check if length of lists is the same
# Out:
# {"a'", "b'", "c''", "d'", "d''", "e'", "e''", "f'", "f''", "g'", "g''"}
# {'1', '2', '4', '8', 'breve'}
# True

# %%
# convert the label lists to NumPy arrays prior to binarization
noteLabels_test = np.array(noteLabels_test)
durationLabels_test = np.array(durationLabels_test)
 
# binarize both sets of labels
noteLabels_test = noteLB.transform(noteLabels_test)
durationLabels_test = durationLB.transform(durationLabels_test)

# %%
# double check if testimages are correctly labeled

noteLB.inverse_transform(noteLabels_test)[0]
durationLB.inverse_transform(durationLabels_test)[0]

plt.imshow(np.squeeze(data_test[0]), cmap = 'gray')
plt.show()

noteLB.inverse_transform(noteLabels_test)[1]
durationLB.inverse_transform(durationLabels_test)[1]

plt.imshow(np.squeeze(data_test[1]), cmap = 'gray')
plt.show()

noteLB.inverse_transform(noteLabels_test)[15]
durationLB.inverse_transform(durationLabels_test)[15]

plt.imshow(np.squeeze(data_test[15]), cmap = 'gray')
plt.show()
# Out:
# "a'"
# '1'
# "a'"
# '4'
# "d''"
# '4'

# %%
# classify test images with model
scores = model.evaluate(data_test, [noteLabels_test, durationLabels_test], verbose=0)

print("[INFO] Total Loss: {:.5f}".format(scores[0]))  
print("[INFO] Note Loss: {:.5f}".format(scores[1])) 
print("[INFO] Duration Loss: {:.5f}".format(scores[2]))  
print("[INFO] Note Accuracy: {:.2f}%".format(scores[3]*100)) 
print("[INFO] Duration Accuracy: {:.2f}%".format(scores[4]*100))
# Out:
# [INFO] Total Loss: 3.32201
# [INFO] Note Loss: 2.02059
# [INFO] Duration Loss: 1.30142
# [INFO] Note Accuracy: 36.67%
# [INFO] Duration Accuracy: 43.33%

# %%
note_pred, duration_pred = model.predict(data_test)
notes_preds = noteLB.inverse_transform(note_pred)
duration_preds = durationLB.inverse_transform(duration_pred)

# %%
note_true, duration_true = noteLabels_test.argmax(axis=-1), durationLabels_test.argmax(axis=-1)
note_pred, duration_pred = note_pred.argmax(axis=-1), duration_pred.argmax(axis=-1)

# %%
print("Classification report for notes")
print(classification_report(note_true, note_pred))

print("\nClassification report for duration")
print(classification_report(duration_true, duration_pred))
# Out:
# Classification report for notes
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.60      0.60      0.60         5
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00         1
#            4       0.60      0.75      0.67         4
#            5       0.40      0.67      0.50         3
#            6       0.50      0.25      0.33         4
#            7       0.00      0.00      0.00         1
#            8       0.20      1.00      0.33         1
#            9       0.00      0.00      0.00         3
#           10       1.00      1.00      1.00         1
#
#     accuracy                           0.37        30
#    macro avg       0.30      0.39      0.31        30
# weighted avg       0.33      0.37      0.33        30
#
#
# Classification report for duration
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73         7
#            1       0.46      0.67      0.55         9
#            2       1.00      0.11      0.20         9
#            3       0.25      0.33      0.29         3
#            4       0.33      0.50      0.40         2
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.43        30
#    macro avg       0.51      0.36      0.36        30
# weighted avg       0.72      0.43      0.45        30

# %%
model.save('InceptionV3_lily.h5')
