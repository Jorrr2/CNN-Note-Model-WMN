# %%
#importing packages
import tensorflow as tf
from tensorflow import keras
from keras.utils import plot_model
from tensorflow.keras import layers, applications, optimizers
from keras import regularizers
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, LeakyReLU, GlobalAveragePooling2D, ZeroPadding2D, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array

from sklearn.preprocessing import MultiLabelBinarizer, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from scipy import ndimage, misc

from imgaug import augmenters as iaa
import imgaug as ia

import numpy as np
import matplotlib.pyplot as plt
from imutils import paths
import imutils
import random
import pickle
import cv2
import os
import argparse
import re
from PIL import Image
from numpy import *
from glob import glob
from datetime import datetime
from shutil import copyfile
 
import pandas as pd    
pd.set_option('display.max_rows', 500)

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell #multiple outputs in notebook
InteractiveShell.ast_node_interactivity = "all"            #

random.seed(42)
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.backend.backend())
# Out:
# 1.15.0
# tensorflow

# %%
def plotImages(images_arr, name):
    random.shuffle(images_arr)
    fig, axes = plt.subplots(1,10, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img.astype('uint8'), cmap = 'gray')
        ax.axis('off')
    plt.tight_layout()
    plt.show()
    fig.savefig('{}.png'.format(name))

# %%
#google Colab
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
#google Colab
# !unzip drive/My\ Drive/notes_aug_heavy_lily.zip

OUTPUT = "notes_aug_heavy/"

# %%
# initialize image dimensions
IMAGE_DIMS = (158, 100, 3)
scale_percent = 100

width = int(IMAGE_DIMS[1] * scale_percent / 100)
height = int(IMAGE_DIMS[0] * scale_percent / 100)

# %%
# grab the image paths and randomly shuffle them
random.seed(42)
imagePaths = sorted(list(paths.list_images(OUTPUT)))
random.shuffle(imagePaths)

# initialize the data and labels
images_train = []
data_train = []
noteLabels = []
durationLabels = []

# create preprocessed lists of images
for imagePath in imagePaths:
    image = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, (width, height))
    ret1, image = cv2.threshold(image,127,255,cv2.THRESH_OTSU)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) #TL model needs colored, 3 channel images as input
    image = ndimage.median_filter(image, size=2)
    images_train.append(image)
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    data_train.append(image)
    
    # extract set of class labels from the image path and update the labels
    filename = imagePath.split(os.path.sep)[-1]
    duration = re.search('(breve|longa|\d\.?)', filename).group()
    note = re.search('([a-z]\'*|^\w{1}\'*)', filename).group()
    noteLabels.append(note)
    durationLabels.append(duration)

# %%
plotImages(images_train, 'images_train')

# %%
data_train = np.array(data_train)

# do some checks
data_train.shape
set(noteLabels)
set(durationLabels)
len(set(map(len, (data_train, noteLabels, durationLabels)))) == 1 #check if length of lists is the same
# Out:
# (19800, 158, 100, 3)
# {"a'", "b'", "c''", "d'", "d''", "e'", "e''", "f'", "f''", "g'", "g''"}
# {'1', '2', '4', '8', 'breve', 'longa'}
# True

# %%
# convert the label lists to NumPy arrays prior to binarization
noteLabels = np.array(noteLabels)
durationLabels = np.array(durationLabels)
 
# binarize both sets of labels
noteLB = LabelBinarizer()
durationLB = LabelBinarizer()
noteLabels = noteLB.fit_transform(noteLabels)
durationLabels = durationLB.fit_transform(durationLabels)

trainX, testX, trainNoteY, testNoteY, trainDurationY, testDurationY = train_test_split(data_train,
                                    noteLabels, durationLabels, random_state=666, train_size=0.75)

# %%
# do some checks

print("We have {} training images and {} test images, with a total of {} images. The images have a height of {} and a width of {} with {} channel(s). There are {} different note classes and {} different duration classes.".format(trainX.shape[0], testX.shape[0], data_train.shape[0], data_train.shape[1], data_train.shape[2], data_train.shape[3], trainNoteY.shape[1], trainDurationY.shape[1]))
# Out:
# We have 14850 training images and 4950 test images, with a total of 19800 images. The images have a height of 158 and a width of 100 with 3 channel(s). There are 11 different note classes and 6 different duration classes.

# %% [markdown]
# # Transfer Model

# %%
base_model = applications.inception_v3.InceptionV3(weights = "imagenet", include_top=False, input_shape = (158, 100, 3))
# base_model = keras.applications.resnet_v2.ResNet50V2(include_top=False, weights='imagenet', input_shape = (158, 100, 3))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 3s 0us/step

# %%
for layer in base_model.layers[:18]:
    layer.trainable = False

# %%
pd.set_option('max_colwidth', -1)
layers = [(layer, layer.name, layer.trainable) for layer in base_model.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                                                                      Layer Type  ... Layer Trainable
# 0    <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fb49aed9ba8>            ...  False
# 1    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49bb6d438>              ...  False
# 2    <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49bb6d6d8>  ...  False
# 3    <tensorflow.python.keras.layers.core.Activation object at 0x7fb49821cc88>                   ...  False
# 4    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49bb6d748>              ...  False
# 5    <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b6a3d68>  ...  False
# 6    <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b3399e8>                   ...  False
# 7    <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b6a3ef0>              ...  False
# 8    <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b1f3518>  ...  False
# 9    <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b228e80>                   ...  False
# 10   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb49b1f3898>              ...  False
# 11   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b156e48>              ...  False
# 12   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b6ec860>  ...  False
# 13   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b70ce10>                   ...  False
# 14   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b6ec898>              ...  False
# 15   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b439e80>  ...  False
# 16   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b45fbe0>                   ...  False
# 17   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb49b2f8f28>              ...  False
# 18   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb498208fd0>              ...  True
# 19   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4979acda0>  ...  True
# 20   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4979c19e8>                   ...  True
# 21   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b1e5e80>              ...  True
# 22   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4979ac2e8>              ...  True
# 23   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb498247d68>  ...  True
# 24   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49aebf128>  ...  True
# 25   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4982575f8>                   ...  True
# 26   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4979ccc88>                   ...  True
# 27   <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb49b11da20>          ...  True
# 28   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b3c4f98>              ...  True
# 29   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb498247c18>              ...  True
# 30   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49aebf400>              ...  True
# 31   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49af0c710>              ...  True
# 32   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b308588>  ...  True
# 33   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4982024a8>  ...  True
# 34   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b11db70>  ...  True
# 35   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49aefeb38>  ...  True
# 36   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b290b00>                   ...  True
# 37   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49820d0b8>                   ...  True
# 38   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49af0e9b0>                   ...  True
# 39   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49aeee5c0>                   ...  True
# 40   <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb49aefeb70>                 ...  True
# 41   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49af623c8>              ...  True
# 42   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49afca828>  ...  True
# 43   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49afe73c8>                   ...  True
# 44   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b0d1b38>              ...  True
# 45   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49afcaac8>              ...  True
# 46   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49afa04e0>  ...  True
# 47   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b02e128>  ...  True
# 48   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49af7f080>                   ...  True
# 49   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b062da0>                   ...  True
# 50   <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb49b0308d0>          ...  True
# 51   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49aeee588>              ...  True
# 52   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49af98e80>              ...  True
# 53   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b031358>              ...  True
# 54   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b018cc0>              ...  True
# 55   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b0d1b00>  ...  True
# 56   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49af62be0>  ...  True
# 57   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b030e48>  ...  True
# 58   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b005c50>  ...  True
# 59   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b0d35c0>                   ...  True
# 60   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49af659b0>                   ...  True
# 61   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b01fac8>                   ...  True
# 62   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b08a6d8>                   ...  True
# 63   <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb49b005c88>                 ...  True
# 64   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4978dbd30>              ...  True
# 65   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4978e8780>  ...  True
# 66   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4978f54e0>                   ...  True
# 67   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b08fc88>              ...  True
# 68   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4978e8ba8>              ...  True
# 69   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497982630>  ...  True
# 70   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4978a1208>  ...  True
# 71   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49798d0b8>                   ...  True
# 72   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4978ac0f0>                   ...  True
# 73   <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb4978cd208>          ...  True
# 74   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49b0999b0>              ...  True
# 75   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497987400>              ...  True
# 76   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4978a7fd0>              ...  True
# 77   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49787ccc0>              ...  True
# 78   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49b08fc50>  ...  True
# 79   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497932ef0>  ...  True
# 80   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4978cd5c0>  ...  True
# 81   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49788bd68>  ...  True
# 82   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49b0726d8>                   ...  True
# 83   <tensorflow.python.keras.layers.core.Activation object at 0x7fb497941ac8>                   ...  True
# 84   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4978628d0>                   ...  True
# 85   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4978957f0>                   ...  True
# 86   <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb49788bda0>                 ...  True
# 87   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497841da0>              ...  True
# 88   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4977fb5c0>  ...  True
# 89   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4978031d0>                   ...  True
# 90   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4977fb710>              ...  True
# 91   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4977acb70>  ...  True
# 92   <tensorflow.python.keras.layers.core.Activation object at 0x7fb4977b9be0>                   ...  True
# 93   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49783bf60>              ...  True
# 94   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4977d5f60>              ...  True
# 95   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497841d68>  ...  True
# 96   <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49775f7f0>  ...  True
# 97   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49784e7f0>                   ...  True
# 98   <tensorflow.python.keras.layers.core.Activation object at 0x7fb49776e5c0>                   ...  True
# 99   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb49775fd68>              ...  True
# 100  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb497795f60>                 ...  True
# 101  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4976b3f28>              ...  True
# 102  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497673908>  ...  True
# 103  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49767b240>                   ...  True
# 104  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4976738d0>              ...  True
# 105  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497623f60>  ...  True
# 106  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497632c18>                   ...  True
# 107  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49779afd0>              ...  True
# 108  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49764cf60>              ...  True
# 109  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497750a90>  ...  True
# 110  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4975dbcc0>  ...  True
# 111  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4976dd438>                   ...  True
# 112  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4975e7630>                   ...  True
# 113  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497750630>              ...  True
# 114  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4975db748>              ...  True
# 115  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4976ea780>  ...  True
# 116  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497614630>  ...  True
# 117  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497710e10>                   ...  True
# 118  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497619ef0>                   ...  True
# 119  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb4975beda0>          ...  True
# 120  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49779a240>              ...  True
# 121  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497715048>              ...  True
# 122  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4976144a8>              ...  True
# 123  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49756ecf8>              ...  True
# 124  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49779af98>  ...  True
# 125  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4976b3ef0>  ...  True
# 126  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4975be400>  ...  True
# 127  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49757beb8>  ...  True
# 128  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497728a20>                   ...  True
# 129  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4976c5828>                   ...  True
# 130  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4975d1a20>                   ...  True
# 131  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497588940>                   ...  True
# 132  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb49757bef0>                 ...  True
# 133  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4974d2ef0>              ...  True
# 134  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49748c470>  ...  True
# 135  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497499128>                   ...  True
# 136  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49748c710>              ...  True
# 137  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49743cda0>  ...  True
# 138  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497449b38>                   ...  True
# 139  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497534ef0>              ...  True
# 140  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497455e80>              ...  True
# 141  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4974ea2e8>  ...  True
# 142  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4973f5cc0>  ...  True
# 143  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4974f7358>                   ...  True
# 144  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497400550>                   ...  True
# 145  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4974ea5f8>              ...  True
# 146  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4973f5860>              ...  True
# 147  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49749be48>  ...  True
# 148  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4973a9240>  ...  True
# 149  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4974a7d30>                   ...  True
# 150  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4973b1f28>                   ...  True
# 151  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb4973cffd0>          ...  True
# 152  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49752dba8>              ...  True
# 153  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4974b4e80>              ...  True
# 154  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4973b6080>              ...  True
# 155  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497388c18>              ...  True
# 156  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497534eb8>  ...  True
# 157  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4974d2a90>  ...  True
# 158  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4973cfcf8>  ...  True
# 159  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497395dd8>  ...  True
# 160  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49753f940>                   ...  True
# 161  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49745d710>                   ...  True
# 162  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49736a940>                   ...  True
# 163  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497320860>                   ...  True
# 164  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb497395e10>                 ...  True
# 165  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497269a20>              ...  True
# 166  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4972247f0>  ...  True
# 167  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497230080>                   ...  True
# 168  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497224748>              ...  True
# 169  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497255e48>  ...  True
# 170  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4971e1a90>                   ...  True
# 171  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49734ce48>              ...  True
# 172  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4971ffcc0>              ...  True
# 173  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497303780>  ...  True
# 174  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49720ca90>  ...  True
# 175  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49730f2b0>                   ...  True
# 176  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4972184a8>                   ...  True
# 177  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497303860>              ...  True
# 178  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49720c438>              ...  True
# 179  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4972b4fd0>  ...  True
# 180  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4971c4240>  ...  True
# 181  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4972bfc88>                   ...  True
# 182  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4971d10b8>                   ...  True
# 183  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb497170f60>          ...  True
# 184  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497346898>              ...  True
# 185  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49725cf28>              ...  True
# 186  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4971caf98>              ...  True
# 187  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49711ec88>              ...  True
# 188  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49734ce10>  ...  True
# 189  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497269b70>  ...  True
# 190  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4971702b0>  ...  True
# 191  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49712cd30>  ...  True
# 192  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49735a898>                   ...  True
# 193  <tensorflow.python.keras.layers.core.Activation object at 0x7fb49727a6a0>                   ...  True
# 194  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497182898>                   ...  True
# 195  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4971387b8>                   ...  True
# 196  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb49712cd68>                 ...  True
# 197  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497086d68>              ...  True
# 198  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4970404a8>  ...  True
# 199  <tensorflow.python.keras.layers.core.Activation object at 0x7fb497045eb8>                   ...  True
# 200  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49704a128>              ...  True
# 201  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496fe8c18>  ...  True
# 202  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496ffa9e8>                   ...  True
# 203  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb4970e6da0>              ...  True
# 204  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496fe8320>              ...  True
# 205  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb49711a5c0>  ...  True
# 206  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496fa6978>  ...  True
# 207  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4970a6208>                   ...  True
# 208  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496fb1400>                   ...  True
# 209  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb49711a710>              ...  True
# 210  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496fa6780>              ...  True
# 211  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4970ccf60>  ...  True
# 212  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496fd9d68>  ...  True
# 213  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4970d9be0>                   ...  True
# 214  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496f64dd8>                   ...  True
# 215  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb496f88ba8>          ...  True
# 216  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497159da0>              ...  True
# 217  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb497066eb8>              ...  True
# 218  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496f602b0>              ...  True
# 219  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496f3aa90>              ...  True
# 220  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb4970e6d68>  ...  True
# 221  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb497086be0>  ...  True
# 222  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496f88128>  ...  True
# 223  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496f47c88>  ...  True
# 224  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4970f17f0>                   ...  True
# 225  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4970935f8>                   ...  True
# 226  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496f1b780>                   ...  True
# 227  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496f52710>                   ...  True
# 228  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496f47cc0>                 ...  True
# 229  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496eb6748>              ...  True
# 230  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496e66d30>  ...  True
# 231  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496e73b00>                   ...  True
# 232  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496e81dd8>              ...  True
# 233  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496e1f630>  ...  True
# 234  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496e2b518>                   ...  True
# 235  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496ef1978>              ...  True
# 236  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496e1fb00>              ...  True
# 237  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496effc88>  ...  True
# 238  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496e56470>  ...  True
# 239  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496f0a710>                   ...  True
# 240  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496de1048>                   ...  True
# 241  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496effcc0>              ...  True
# 242  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496ddddd8>              ...  True
# 243  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496eb6898>  ...  True
# 244  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496dfdcf8>  ...  True
# 245  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496ec2128>                   ...  True
# 246  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496e12908>                   ...  True
# 247  <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fb496dfdf98>              ...  True
# 248  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496db2cf8>                 ...  True
# 249  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496d0f780>              ...  True
# 250  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496d15f60>  ...  True
# 251  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496ca4a20>                   ...  True
# 252  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496dd7e80>              ...  True
# 253  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496d15f98>              ...  True
# 254  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496d76a90>  ...  True
# 255  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496ccea20>  ...  True
# 256  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496d81748>                   ...  True
# 257  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496cda438>                   ...  True
# 258  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496d76ef0>              ...  True
# 259  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496d2f710>              ...  True
# 260  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496cce5f8>              ...  True
# 261  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496c92048>              ...  True
# 262  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb496bec8d0>          ...  True
# 263  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496dc06a0>              ...  True
# 264  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496d2f470>  ...  True
# 265  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496cdfda0>  ...  True
# 266  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496c67780>  ...  True
# 267  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496c30be0>  ...  True
# 268  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496becc88>              ...  True
# 269  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496dc0978>  ...  True
# 270  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496d3a160>                   ...  True
# 271  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496ceab38>                   ...  True
# 272  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496c8ce10>                   ...  True
# 273  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496c45828>                   ...  True
# 274  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496bf2b00>  ...  True
# 275  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496dcbd30>                   ...  True
# 276  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496cf7e80>                 ...  True
# 277  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496c30240>                 ...  True
# 278  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496bfdc18>                   ...  True
# 279  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496c1af60>                 ...  True
# 280  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496af9400>              ...  True
# 281  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496afceb8>  ...  True
# 282  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496b0c940>                   ...  True
# 283  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496bd0eb8>              ...  True
# 284  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496afcef0>              ...  True
# 285  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496b5d630>  ...  True
# 286  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496ab82e8>  ...  True
# 287  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496b6c668>                   ...  True
# 288  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496ac7358>                   ...  True
# 289  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496b5dba8>              ...  True
# 290  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496b96588>              ...  True
# 291  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496ab85f8>              ...  True
# 292  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496a81e80>              ...  True
# 293  <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x7fb496a4ce10>          ...  True
# 294  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496ba2d68>              ...  True
# 295  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496b96710>  ...  True
# 296  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496b3ef98>  ...  True
# 297  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496a6ae48>  ...  True
# 298  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496a1fdd8>  ...  True
# 299  <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fb496a4ca58>              ...  True
# 300  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496ba7c18>  ...  True
# 301  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496b22048>                   ...  True
# 302  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496b56a58>                   ...  True
# 303  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496a76d30>                   ...  True
# 304  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496a2f748>                   ...  True
# 305  <tensorflow.python.keras.layers.normalization.BatchNormalization object at 0x7fb496a59a20>  ...  True
# 306  <tensorflow.python.keras.layers.core.Activation object at 0x7fb496bb3c50>                   ...  True
# 307  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496b4af60>                 ...  True
# 308  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb496a1fc18>                 ...  True
# 309  <tensorflow.python.keras.layers.core.Activation object at 0x7fb4969e5b38>                   ...  True
# 310  <tensorflow.python.keras.layers.merge.Concatenate object at 0x7fb4969f2e10>                 ...  True
#
# [311 rows x 3 columns]

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.2)(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.2)(x)
note_output = Dense(len(noteLB.classes_), activation='softmax', name = "note_output")(x)
duration_output = Dense(len(durationLB.classes_), activation='softmax', name = "duration_output")(x)

model = Model(inputs=base_model.input, outputs=[note_output, duration_output])

# %%
# do some checks
model.summary()
model.input_shape
model.output_shape
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 158, 100, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 78, 49, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 78, 49, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 78, 49, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 76, 47, 32)   9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 76, 47, 32)   96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 76, 47, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 76, 47, 64)   18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 76, 47, 64)   192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 76, 47, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 37, 23, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 37, 23, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 37, 23, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 37, 23, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 35, 21, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 35, 21, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 35, 21, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 17, 10, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 17, 10, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 17, 10, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 17, 10, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 17, 10, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 17, 10, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 17, 10, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 17, 10, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 17, 10, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 17, 10, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 17, 10, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 17, 10, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 17, 10, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 17, 10, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 17, 10, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 17, 10, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 17, 10, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 17, 10, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 17, 10, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 17, 10, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 17, 10, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 17, 10, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 17, 10, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 17, 10, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 17, 10, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 17, 10, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 17, 10, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 17, 10, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None,
456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 8, 4, 192)    576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 8, 4, 192)    576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 8, 4, 192)    576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 8, 4, 192)    576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8, 4, 192)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 8, 4, 192)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 8, 4, 192)    0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 8, 4, 192)    0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 8, 4, 768)    0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 1, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 1, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 3, 1, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 3, 1, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 3, 1, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 3, 1, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 1, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 3, 1, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 3, 1, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 3, 1, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 3, 1, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 1, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 1, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 3, 1, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 3, 1, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 3, 1, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 3, 1, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 3, 1, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 3, 1, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 3, 1, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 3, 1, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 3, 1, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 3, 1, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 3, 1, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 3, 1, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 1, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 1, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 1, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 1, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 3, 1, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 1, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 3, 1, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3, 1, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 1, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 3, 1, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 3, 1, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 3, 1, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 3, 1, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 3, 1, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 3, 1, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 3, 1, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 3, 1, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 3, 1, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 3, 1, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 3, 1, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 3, 1, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 3, 1, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 3, 1, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 3, 1, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 3, 1, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 3, 1, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 3, 1, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 3, 1, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 3, 1, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 3, 1, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 3, 1, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 3, 1, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 3, 1, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 3, 1, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 3, 1, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 3, 1, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 3, 1, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 3, 1, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 1, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 3, 1, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 3, 1, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 6144)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          1573120     flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# note_output (Dense)             (None, 11)           2827        dropout_1[0][0]
# __________________________________________________________________________________________________
# duration_output (Dense)         (None, 6)            1542        dropout_1[0][0]
# ==================================================================================================
# Total params: 23,446,065
# Trainable params: 23,239,361
# Non-trainable params: 206,704
# __________________________________________________________________________________________________
# (None, 158, 100, 3)
# [(None, 11), (None, 6)]

# %%
# compile model
epochs = 80
batch_size = 128

# define two dictionaries: one that specifies the loss method for
# each output of the network along with a second dictionary that
# specifies the weight per loss
losses = {
    "note_output": "categorical_crossentropy",
    "duration_output": "categorical_crossentropy",}
lossWeights = {"note_output": 1.0, "duration_output": 1.0}
 
# initialize the optimizer and compile the model
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
rms = optimizers.RMSprop(learning_rate=0.001, rho=0.9)
adam = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
nadam = optimizers.Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=adam, loss=losses, loss_weights=lossWeights, metrics=["accuracy"])

# %%
# callbacks
early_stopping = EarlyStopping(monitor='val_note_output_acc', patience=12, mode = 'max', verbose = 1)

reduce_lr = ReduceLROnPlateau(patience=8, monitor='val_loss', factor=0.3, min_lr=0.00001, cooldown=1, verbose=1)

checkpoint = ModelCheckpoint("/Users/annaleid/Documents/Jordy/Trained Models/",
        monitor='val_acc', 
        save_best_only=True, 
        mode='max',
        verbose=0)

# %%
# # train the network to perform multi-output classification
H = model.fit(trainX, {"note_output": trainNoteY, "duration_output": trainDurationY},
    validation_data=(testX, {"note_output": testNoteY, "duration_output": testDurationY}),
    epochs=epochs,
    verbose=1,
    callbacks = [reduce_lr, early_stopping])
# Out:
# Train on 14850 samples, validate on 4950 samples
# Epoch 1/80
# 14850/14850 [==============================] - 136s 9ms/sample - loss: 0.6292 - note_output_loss: 0.3955 - duration_output_loss: 0.2339 - note_output_acc: 0.8732 - duration_output_acc: 0.9248 - val_loss: 0.7669 - val_note_output_loss: 0.5926 - val_duration_output_loss: 0.1728 - val_note_output_acc: 0.9091 - val_duration_output_acc: 0.9499
lossNames = ["loss", "note_output_loss", "duration_output_loss"]
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))
 
# loop over the loss names
for (i, l) in enumerate(lossNames):
    # plot the loss for both the training and validation data
    title = "Loss for {}".format(l) if l != "loss" else "Total loss"
    ax[i].set_title(title)
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Loss")
    ax[i].plot(np.arange(0, n_epochs), H.history[l], label=l)
    ax[i].plot(np.arange(0, n_epochs), H.history["val_" + l],
        label="val_" + l)
    ax[i].legend()
 
# save the losses figure and create a new figure for the accuracies
plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Total loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')
# Text(0.5, 1.0, 'Loss for note_output_loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')
# Text(0.5, 1.0, 'Loss for duration_output_loss')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Loss')

# %%
# create a new figure for the accuracies
accuracyNames = ["note_output_acc", "duration_output_acc"]
plt.style.use("ggplot")
(fig, ax) = plt.subplots(2, 1, figsize=(8, 8))
 
# loop over the accuracy names
for (i, l) in enumerate(accuracyNames):
    # plot the loss for both the training and validation data
    ax[i].set_title("Accuracy for {}".format(l))
    ax[i].set_xlabel("Epoch #")
    ax[i].set_ylabel("Accuracy")
    ax[i].plot(np.arange(0, n_epochs), H.history[l], label=l)
    ax[i].plot(np.arange(0, n_epochs), H.history["val_" + l],
        label="val_" + l)
    ax[i].legend()
 
# save the accuracies figure
plt.tight_layout()
# Out:
# Text(0.5, 1.0, 'Accuracy for note_output_acc')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Accuracy for duration_output_acc')
# Text(0.5, 0, 'Epoch #')
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# # Test Images

# %%
#Google Colab
# !unzip drive/My\ Drive/testimages.zip

# %%
folder_test = "testimages/"
imagePaths = sorted(list(paths.list_images(folder_test)))

##### Create list with arrays and labels of test images

# initialize the data and labels
images_test_original = []
images_test = []
data_test = []
noteLabels_test = []
durationLabels_test = []

for imagePath in imagePaths:
    image = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)
    images_test_original.append(image)
    image = cv2.resize(image, (width, height))
    ret1, image = cv2.threshold(image, 50,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) #TL model needs colored, 3 channel images as input
    image = ndimage.median_filter(image, size=2)
    images_test.append(image)
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    data_test.append(image)
    
    # extract set of class labels from the image path and update the labels
    # update the respective lists
    filename = imagePath.split(os.path.sep)[-1]
    duration = re.search('(breve|longa|maxima|\d\.?)', filename).group()
    note = re.search('([a-z]\'*|^\w{1}\'*)', filename).group()
    noteLabels_test.append(note)
    durationLabels_test.append(duration)

# %%
plotImages(images_test_original, 'test_original')

# %%
plotImages(images_test, 'test_preprocessed')

# %%
data_test = np.array(data_test)

# %%
set(noteLabels_test)
set(durationLabels_test)
len(set(map(len, (data_test, noteLabels_test, durationLabels_test)))) == 1 #check if length of lists is the same
# Out:
# {"a'", "b'", "c''", "d'", "d''", "e'", "e''", "f'", "f''", "g'", "g''"}
# {'1', '2', '4', '8', 'breve'}
# True

# %%
# convert the label lists to NumPy arrays prior to binarization
noteLabels_test = np.array(noteLabels_test)
durationLabels_test = np.array(durationLabels_test)
 
# binarize both sets of labels
noteLabels_test = noteLB.transform(noteLabels_test)
durationLabels_test = durationLB.transform(durationLabels_test)

# %%
# double check if testimages are correctly labeled

noteLB.inverse_transform(noteLabels_test)[0]
durationLB.inverse_transform(durationLabels_test)[0]

plt.imshow(np.squeeze(data_test[0]), cmap = 'gray')
plt.show()

noteLB.inverse_transform(noteLabels_test)[1]
durationLB.inverse_transform(durationLabels_test)[1]

plt.imshow(np.squeeze(data_test[1]), cmap = 'gray')
plt.show()

noteLB.inverse_transform(noteLabels_test)[15]
durationLB.inverse_transform(durationLabels_test)[15]

plt.imshow(np.squeeze(data_test[15]), cmap = 'gray')
plt.show()
# Out:
# "a'"
# '1'
# "a'"
# '4'
# "d''"
# '4'

# %%
# classify test images with model
scores = model.evaluate(data_test, [noteLabels_test, durationLabels_test], verbose=0)

print("[INFO] Total Loss: {:.5f}".format(scores[0]))  
print("[INFO] Note Loss: {:.5f}".format(scores[1])) 
print("[INFO] Duration Loss: {:.5f}".format(scores[2]))  
print("[INFO] Note Accuracy: {:.2f}%".format(scores[3]*100)) 
print("[INFO] Duration Accuracy: {:.2f}%".format(scores[4]*100))
# Out:
# [INFO] Total Loss: 2.66315
# [INFO] Note Loss: 1.74901
# [INFO] Duration Loss: 0.91414
# [INFO] Note Accuracy: 46.67%
# [INFO] Duration Accuracy: 76.67%

# %%
note_pred, duration_pred = model.predict(data_test)
notes_preds = noteLB.inverse_transform(note_pred)
duration_preds = durationLB.inverse_transform(duration_pred)

# %%
note_true, duration_true = noteLabels_test.argmax(axis=-1), durationLabels_test.argmax(axis=-1)
note_pred, duration_pred = note_pred.argmax(axis=-1), duration_pred.argmax(axis=-1)

# %%
print("Classification report for notes")
print(classification_report(note_true, note_pred))

print("\nClassification report for duration")
print(classification_report(duration_true, duration_pred))
# Out:
# Classification report for notes
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         3
#            1       1.00      0.60      0.75         5
#            2       0.00      0.00      0.00         4
#            3       0.00      0.00      0.00         1
#            4       0.43      0.75      0.55         4
#            5       0.50      0.67      0.57         3
#            6       0.00      0.00      0.00         4
#            7       0.00      0.00      0.00         1
#            8       0.14      1.00      0.25         1
#            9       1.00      0.67      0.80         3
#           10       0.33      1.00      0.50         1
#
#     accuracy                           0.47        30
#    macro avg       0.35      0.49      0.36        30
# weighted avg       0.44      0.47      0.42        30
#
#
# Classification report for duration
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88         7
#            1       1.00      0.78      0.88         9
#            2       0.70      0.78      0.74         9
#            3       1.00      0.33      0.50         3
#            4       1.00      0.50      0.67         2
#            5       0.00      0.00      0.00         0
#
#     accuracy                           0.77        30
#    macro avg       0.75      0.56      0.61        30
# weighted avg       0.86      0.77      0.78        30

# %%
model.save('InceptionV3_lily.h5')
